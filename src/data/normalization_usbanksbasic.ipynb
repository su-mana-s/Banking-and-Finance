# %%
import boto3
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
# AWS credentials and region
aws_access_key_id = 'AKIAW3MED5OHMTBP3VFW'
aws_secret_access_key = '/UG/lOcC9fY3PbBhSxSecPnLX4i6V1kLR29TUZd8'
region_name = 'ap-south-1'  # e.g., 'us-east-1'

# %%
# Initialize S3 client
s3 = boto3.client('s3', 
                  aws_access_key_id=aws_access_key_id,
                  aws_secret_access_key=aws_secret_access_key,
                  region_name=region_name)

# %%
# S3 bucket and file key
bucket_name = 'usbanksbasic'
file_key = 'Final_USBankBasics.csv'

# %%
# Download the file from S3 and load into DataFrame
response = s3.get_object(Bucket=bucket_name, Key=file_key)
data = pd.read_csv(response['Body'],header=0)
data.head()
# Out:
#                                          Tag                 Bank  \
# 0                            # of Employees:  jpmorgan-chase-bank
# 1                              Total Assets:  jpmorgan-chase-bank
# 2  Cash and due from depository institutions  jpmorgan-chase-bank
# 3                  Interest-bearing balances  jpmorgan-chase-bank
# 4                                 Securities  jpmorgan-chase-bank
#
#      2023-12-31    2023-09-30    2023-06-30    2023-03-31    2022-12-31  \
# 0  2.268220e+05  2.266490e+05  2.198300e+05  2.218520e+05  2.202710e+05
# 1  3.395126e+12  3.385581e+12  3.382195e+12  3.267963e+12  3.201942e+12
# 2  6.253440e+11  5.126060e+11  4.956780e+11  5.510180e+11  5.685460e+11
# 3  5.965600e+11  4.879120e+11  4.698950e+11  5.261900e+11  5.412880e+11
# 4  5.720990e+11  5.863500e+11  6.130450e+11  6.100410e+11  6.311230e+11
#
#      2022-09-30    2022-06-30    2022-03-31  ...    2002-12-31    2001-12-31  \
# ...

# %%
first_two_columns = data[['Tag', 'Bank']]
first_two_columns.head()
# Out:
#                                          Tag                 Bank
# 0                            # of Employees:  jpmorgan-chase-bank
# 1                              Total Assets:  jpmorgan-chase-bank
# 2  Cash and due from depository institutions  jpmorgan-chase-bank
# 3                  Interest-bearing balances  jpmorgan-chase-bank
# 4                                 Securities  jpmorgan-chase-bank

# %%
# Exclude the columns "Breakdown" and "Bank" from the DataFrame
data_subset = data.drop(columns=['Tag', 'Bank'])

# %%
# Perform data normalization (example: Min-Max scaling) on remaining columns
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(data_subset)

# %%
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(data.iloc[:, 2:])

# %%
# Convert normalized data back to DataFrame
normalized_df = pd.DataFrame(normalized_data, columns=data_subset.columns)

# %%
# Concatenate the columns "Breakdown" and "Bank" with the normalized DataFrame
normalized_df_with_columns = pd.concat([first_two_columns, normalized_df], axis=1)
normalized_df_with_columns.head()
# Out:
#                                          Tag                 Bank  2023-12-31  \
# 0                            # of Employees:  jpmorgan-chase-bank    0.000052
# 1                              Total Assets:  jpmorgan-chase-bank    0.061958
# 2  Cash and due from depository institutions  jpmorgan-chase-bank    0.011454
# 3                  Interest-bearing balances  jpmorgan-chase-bank    0.010930
# 4                                 Securities  jpmorgan-chase-bank    0.010484
#
#    2023-09-30  2023-06-30  2023-03-31  2022-12-31  2022-09-30  2022-06-30  \
# 0    0.000095    0.000091    0.000092    0.000351    0.000382    0.000279
# 1    0.061185    0.057489    0.053965    0.060493    0.060095    0.059552
# 2    0.009345    0.008503    0.009176    0.011030    0.012030    0.012035
# 3    0.008899    0.008066    0.008766    0.010518    0.011595    0.011566
# 4    0.010675    0.010495    0.010149    0.012205    0.011540    0.011914
#
# ...
