# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
liq = pd.read_csv("../../outputs/liquidity.csv")
liq.head()
# Out:
#          Date Cash, Cash Equivalents & Federal Funds Sold  \
# 0        Bank                                         BAC
# 1  12/31/2023                                 622,043,000
# 2  12/31/2022                                 237,462,000
# 3  12/31/2021                                 606,085,000
# 4  12/31/2020                                 387,009,000
#
#   Available for Sale Securities Trading Securities  \
# 0                           BAC                BAC
# 1                    10,203,000        146,539,000
# 2                 1,038,974,000         47,179,000
# 3                     8,895,000        143,646,000
# 4                   920,006,000      1,026,344,000
#
#   Other Short Term Investments Loans Held for Sale Accounts receivable  \
# 0                          BAC                 BAC                 BAC
# 1                  266,649,000           6,002,000          81,881,000
# 2                  199,813,000          11,510,000         195,635,000
# ...

# %%
q = liq["quickRaito"][1:]
c=  liq["currentRatio"][1:]
qa = liq["quickAssets"][1:]	
ca = liq["currentAssets"][1:]	
cl = liq["currentLiabilities"][1:]	
rats = {'qa': qa, 'ca':ca, 'cl':cl}
labels = liq["Date"][1:]

# %% [markdown]
# What is my y axis even doing?

# %%
x = np.arange(4)  # the label locations

width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in rats.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    # ax.bar_label(measurement, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
# ax.set_ylabel('Ratio')
# ax.set_title('Quick and Current Ratios')
ax.set_xticks(x + width, labels)
ax.legend(loc='upper left')
# ax.set_ylim(-0, 8)
plt.show()

# %%
X = labels

q = liq["quickRaito"][1:]
c=  liq["currentRatio"][1:]
rats = {'quick': q, 'current':c}
labels = liq["Date"][1:]

X_axis = np.arange(len(X)) 

plt.bar(X_axis - 0.2, q, 0.4, label = 'Quick') 

plt.bar(X_axis + 0.2, c, 0.4, label = 'Current') 
plt.xticks(X_axis, X) 
# plt.xlabel("Groups") 
plt.title("Quick and Current Ratios") 
plt.legend() 
plt.show()
